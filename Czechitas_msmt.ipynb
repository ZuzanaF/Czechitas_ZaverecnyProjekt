# %%
# Projekt Michaely Hořínkové a Zuzany Foltýnové v rámci Digitální akademie Czechitas, 12/2019

# %%
import pandas as pd

# %%
#konstanty
roky = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
vvs = ['11','12','13','14','15','16','17','18','19','21','22','23','24','25','26','27','28','31','41','43','51','52','53','54']

# %%
# kody a názvy VŠ do dictionary 
# kody_vs = dict(zip(df1[df1.id.str[-3:] == '000']['id_skola'],df1[df1.id.str[-3:] == '000']['fakulta']))
kody_vs = {'11': 'Univerzita Karlova',
 '12': 'Jihočeská univerzita v Českých Budějovicích',
 '13': 'Univerzita J. E. Purkyně v Ústí nad Labem',
 '14': 'Masarykova univerzita',
 '15': 'Univerzita Palackého v Olomouci',
 '16': 'Veterinární a farmaceutická univerzita  Brno',
 '17': 'Ostravská univerzita',
 '18': 'Univerzita  Hradec Králové',
 '19': 'Slezská univerzita v Opavě',
 '21': 'České vysoké učení technické  v Praze',
 '22': 'Vysoká škola chemicko-technologická  v Praze',
 '23': 'Západočeská univerzita v Plzni',
 '24': 'Technická univerzita v Liberci',
 '25': 'Univerzita Pardubice',
 '26': 'Vysoké učení technické v Brně',
 '27': 'Vysoká škola báňská - Technická univerzita  Ostrava',
 '28': 'Univerzita Tomáše Bati ve Zlíně',
 '31': 'Vysoká škola ekonomická v Praze',
 '41': 'Česká zemědělská univerzita v Praze',
 '43': 'Mendelova univerzita',
 '51': 'Akademie múzických umění v Praze',
 '52': 'Akademie výtvarných umění v Praze',
 '53': 'Vysoká škola umělecko-průmyslová v Praze',
 '54': 'Janáčkova akademie múzických umění v Brně',
 '55': 'Vysoká škola polytechnická Jihlava',
 '56': 'Vysoká škola technická a ekonomická v Českých Budějovicích',
 '61': 'Vysoká škola regionálního rozvoje a Bankovní institut - AMBIS, a.s.',
 '62': 'Evropský polytechnický institut, s.r.o.',
 '63': 'Vysoká škola hotelová v Praze, s.r.o.',
 '6D': 'University of New York in Prague, s.r.o',
 '6F': 'Vysoká škola mezinárodních a veřejných vztahů Praha, o.p.s.',
 '6J': 'Academia Rerum Civilium',
 '6K': 'Vysoká škola evropských a regionálních studií, o.p.s.',
 '6N': 'Filmová akademie Miroslava Ondříčka v Písku, o.p.s.',
 '6P': 'Vysoká škola tělesné výchovy a sportu Palestra',
 '6Q': 'Newton College, a.s.',
 '6R': 'Vysoká škola logistiky o.p.s.',
 '6S': 'Vysoká škola zdravotnická, o.p.s.',
 '6T': 'B.I.B.S., a.s.',
 '72': 'Vysoká škola obchodní v Praze, o.p.s.',
 '73': 'Akademie STING, o.p.s',
 '75': 'Metropolitní univerzita Praha, o.p.s.',
 '76': 'Univerzita Jana Amose Komenského Praha, s.r.o.',
 '77': 'Vysoká škola Karla Engliše, a. s.',
 '78': 'Anglo-americká vysoká škola, o.p.s.',
 '79': 'Pražská vysoká škola psychosociálních studií, s.r.o.',
 '7A': 'Západomoravská vysoká škola Třebíč, o.p.s.',
 '7B': 'Soukromá vysoká škola ekonomická Znojmo s.r.o.',
 '7C': 'Moravská vysoká škola Olomouc o.p.s.',
 '7D': 'CEVRO institut z.ú.',
 '7E': 'Unicorn College s.r.o.',
 '7G': 'Vysoká škola obchodní a hotelová, s.r.o.',
 '7J': 'VŠ sociálně správní, ICV Havířov, o.p.s.',
 '7L': 'AKCENT College, s.r.o.',
 '7M': 'Archip s.r.o.',
 '7N': 'Vysoká škola aplikované psychologie, s.r.o.',
 '7P': 'ŠKODA AUTO VŠ, o.p.s.',
 '7R': 'ART & DESIGN INSTITUT, s.r.o.',
 '7S': 'Vysoká škola podnikání a práva, a.s.',
 '7T': 'Vysoká škola kreativní komunikace',
 '7U': 'Vysoká škola finanční a správní, a.s.',
 '7V': 'Vysoká škola ekonomie a managementu, a.s.'}

# %%
#TABULKA 1: https://dsia.msmt.cz//vystupy/f2/f21.xlsx  (studenti celkem včetně cizinců): 2011-2018
#názvy sloupců bez přípony
#přejmenováva df a sloupce a změna nazvu souboru
df = pd.DataFrame(columns=['id', 'fakulta', 'celkem', 'prez_celkem', 'prez_bc', 'prez_mgr', 'prez_nmgr', 'prez_phd',
                           'komb_celkem', 'komb_bc', 'komb_mgr', 'komb_nmgr', 'komb_phd'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f2/f21.xlsx', sheet_name=rok, skiprows=9, skipfooter=2, header=None,
                      usecols=[1, 2] + list(range(6,17)))
  df1.columns = ['id', 'fakulta', 'celkem', 'prez_celkem', 'prez_bc', 'prez_mgr', 'prez_nmgr', 'prez_phd', 'komb_celkem',
                 'komb_bc', 'komb_mgr', 'komb_nmgr', 'komb_phd']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]
 
  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  
  
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  
  # nakonec spojit df a df1
  df = pd.concat([df, df1], ignore_index=True, sort=False)

# %%
df
# Out:
#          id  ...                                      skola
# 0     11110  ...                         Univerzita Karlova
# 1     11120  ...                         Univerzita Karlova
# 2     11130  ...                         Univerzita Karlova
# 3     11140  ...                         Univerzita Karlova
# 4     11150  ...                         Univerzita Karlova
# ...     ...  ...                                        ...
# 1196  51110  ...           Akademie múzických umění v Praze
# 1197  51210  ...           Akademie múzických umění v Praze
# 1198  51310  ...           Akademie múzických umění v Praze
# 1199  54510  ...  Janáčkova akademie múzických umění v Brně
# 1200  54530  ...  Janáčkova akademie múzických umění v Brně
#
# [1201 rows x 16 columns]

# %%
#df[df.id == '23310'][['rok','prez_celkem']].plot(kind='line', ylim=(0,800))

# %%
#TABULKA 2: https://dsia.msmt.cz//vystupy/f2/f21_cr.xlsx  (pouze občani ČR): 2011-2018
#názvy sloupců - přípona: CR
# přejmenováva df a sloupce a změna nazvu souboru
df_CR = pd.DataFrame(columns=['id', 'fakulta', 'celkem_CR', 'prez_celkem_CR', 'prez_bc_CR', 'prez_mgr_CR', 'prez_nmgr_CR', 'prez_phd_CR', 'komb_celkem_CR', 'komb_bc_CR', 'komb_mgr_CR', 'komb_nmgr_CR', 'komb_phd_CR'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f2/f21_cr.xlsx', sheet_name=rok, 
                      skiprows=9, skipfooter=2, header=None, usecols=[1, 2] + list(range(6,17)))
  df1.columns = ['id', 'fakulta', 'celkem_CR', 'prez_celkem_CR', 'prez_bc_CR', 
                 'prez_mgr_CR', 'prez_nmgr_CR', 'prez_phd_CR', 'komb_celkem_CR', 
                 'komb_bc_CR', 'komb_mgr_CR', 'komb_nmgr_CR', 'komb_phd_CR']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]

  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  #
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  #
  #
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  #
  # nakonec spojit df a df1
  df_CR = pd.concat([df_CR, df1], ignore_index=True, sort=False)

# %%
df_CR
# Out:
#          id  ...                                      skola
# 0     11110  ...                         Univerzita Karlova
# 1     11120  ...                         Univerzita Karlova
# 2     11130  ...                         Univerzita Karlova
# 3     11140  ...                         Univerzita Karlova
# 4     11150  ...                         Univerzita Karlova
# ...     ...  ...                                        ...
# 1196  51110  ...           Akademie múzických umění v Praze
# 1197  51210  ...           Akademie múzických umění v Praze
# 1198  51310  ...           Akademie múzických umění v Praze
# 1199  54510  ...  Janáčkova akademie múzických umění v Brně
# 1200  54530  ...  Janáčkova akademie múzických umění v Brně
#
# [1201 rows x 16 columns]

# %%
print(df.shape)
print(df_CR.shape)
#sloučit tabulku k df
df = df.merge(df_CR,how='outer', on=['id', 'id_skola', 'rok', 'skola', 'fakulta'])
print(df.shape)
# Out:
# (1201, 16)
# (1201, 16)
# (1201, 27)

# %%
df.columns
# Out:
# Index(['id', 'fakulta', 'celkem', 'prez_celkem', 'prez_bc', 'prez_mgr',
#        'prez_nmgr', 'prez_phd', 'komb_celkem', 'komb_bc', 'komb_mgr',
#        'komb_nmgr', 'komb_phd', 'rok', 'id_skola', 'skola', 'celkem_CR',
#        'prez_celkem_CR', 'prez_bc_CR', 'prez_mgr_CR', 'prez_nmgr_CR',
#        'prez_phd_CR', 'komb_celkem_CR', 'komb_bc_CR', 'komb_mgr_CR',
#        'komb_nmgr_CR', 'komb_phd_CR'],
#       dtype='object')

# %%
df
# Out:
#          id                             fakulta  ... komb_nmgr_CR komb_phd_CR
# 0     11110                 1. lékařská fakulta  ...            0         494
# 1     11120                 3. lékařská fakulta  ...            0         152
# 2     11130                 2. lékařská fakulta  ...            0         216
# 3     11140            Lékařská fakulta v Plzni  ...            0         118
# 4     11150  Lékařská fakulta v Hradci  Králové  ...            0         202
# ...     ...                                 ...  ...          ...         ...
# 1196  51110           Hudební a taneční fakulta  ...            0           7
# 1197  51210                   Divadelní fakulta  ...           25          10
# 1198  51310         Filmová a televizní fakulta  ...            0           8
# 1199  54510                     Hudební fakulta  ...            0          22
# 1200  54530                   Divadelní fakulta  ...            7           5
#
# [1201 rows x 27 columns]

# %%
#TABULKA 3:  https://dsia.msmt.cz//vystupy/f2/f21_ciz.xlsx  (pouze cizinci): 2011-2018
#názvy sloupců - přípona: CI
# přejmenováva df a sloupce a změna nazvu souboru
df_CI = pd.DataFrame(columns=['id', 'fakulta', 'celkem_CI', 'prez_celkem_CI', 'prez_bc_CI', 'prez_mgr_CI', 'prez_nmgr_CI', 'prez_phd_CI', 'komb_celkem_CI', 'komb_bc_CI', 'komb_mgr_CI', 'komb_nmgr_CI', 'komb_phd_CI'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f2/f21_ciz.xlsx', sheet_name=rok, skiprows=9, skipfooter=2, header=None, usecols=[1, 2] + list(range(6,17)))
  df1.columns = ['id', 'fakulta', 'celkem_CI', 'prez_celkem_CI', 'prez_bc_CI', 'prez_mgr_CI', 'prez_nmgr_CI', 'prez_phd_CI', 'komb_celkem_CI', 'komb_bc_CI', 'komb_mgr_CI', 'komb_nmgr_CI', 'komb_phd_CI']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]
  
  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  #
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  #
  #
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  #
  # nakonec spojit df a df1
  df_CI = pd.concat([df_CI, df1], ignore_index=True, sort=False)

# %%
print(df.shape)
print(df_CR.shape)
#sloučit tabulku k df (změnit příponu)
df = df.merge(df_CI,how='outer', on=['id', 'id_skola', 'rok', 'skola', 'fakulta'])
print(df.shape)
# Out:
# (1201, 27)
# (1201, 16)
# (1201, 38)

# %%
df.sample(3)
# Out:
#         id                            fakulta  ... komb_nmgr_CI komb_phd_CI
# 567  27900             celoškolská pracoviště  ...            0           0
# 358  18450  Fakulta informatiky a managementu  ...            0           1
# 346  15410                Pedagogická fakulta  ...            1           7
#
# [3 rows x 38 columns]

# %%
#TABULKA 4: https://dsia.msmt.cz//vystupy/f2/f21z.xlsx   (pouze ženy včetně cizinců): 2011 - 2018
#názvy sloupců - přípona Z
# přejmenováva df a sloupce a změna nazvu souboru
df_Z = pd.DataFrame(columns=['id', 'fakulta', 'celkem_Z', 'prez_celkem_Z', 'prez_bc_Z', 'prez_mgr_Z', 'prez_nmgr_Z', 'prez_phd_Z', 'komb_celkem_Z', 'komb_bc_Z', 'komb_mgr_Z', 'komb_nmgr_Z', 'komb_phd_Z'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f2/f21z.xlsx', sheet_name=rok, skiprows=9, skipfooter=2, header=None, usecols=[1, 2] + list(range(6,17)))
  df1.columns = ['id', 'fakulta', 'celkem_Z', 'prez_celkem_Z', 'prez_bc_Z', 'prez_mgr_Z', 'prez_nmgr_Z', 'prez_phd_Z', 'komb_celkem_Z', 'komb_bc_Z', 'komb_mgr_Z', 'komb_nmgr_Z', 'komb_phd_Z']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]

  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  #
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  #
  #
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  #
  # nakonec spojit df a df1
  df_Z = pd.concat([df_Z, df1], ignore_index=True, sort=False)

# %%
df_Z
# Out:
#          id  ...                                      skola
# 0     11110  ...                         Univerzita Karlova
# 1     11120  ...                         Univerzita Karlova
# 2     11130  ...                         Univerzita Karlova
# 3     11140  ...                         Univerzita Karlova
# 4     11150  ...                         Univerzita Karlova
# ...     ...  ...                                        ...
# 1196  51110  ...           Akademie múzických umění v Praze
# 1197  51210  ...           Akademie múzických umění v Praze
# 1198  51310  ...           Akademie múzických umění v Praze
# 1199  54510  ...  Janáčkova akademie múzických umění v Brně
# 1200  54530  ...  Janáčkova akademie múzických umění v Brně
#
# [1201 rows x 16 columns]

# %%
print(df.shape)
print(df_Z.shape)
#sloučit tabulku k df
df = df.merge(df_Z,how='outer', on=['id', 'id_skola', 'rok', 'skola', 'fakulta'])
print(df.shape)
# Out:
# (1201, 38)
# (1201, 16)
# (1201, 49)

# %%
#TABULKA 5: https://dsia.msmt.cz//vystupy/f2/f21z_cr.xlsx (pouze ženy občanky ČR) 2011 - 2018
#názvy sloupců - přípona ZCR
# přejmenováva df a sloupce a změna nazvu souboru
df_ZCR = pd.DataFrame(columns=['id', 'fakulta', 'celkem_ZCR', 'prez_celkem_ZCR', 'prez_bc_ZCR', 'prez_mgr_ZCR', 'prez_nmgr_ZCR', 'prez_phd_ZCR', 'komb_celkem_ZCR', 'komb_bc_ZCR', 'komb_mgr_ZCR', 'komb_nmgr_ZCR', 'komb_phd_ZCR'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f2/f21z_cr.xlsx', sheet_name=rok, skiprows=9, skipfooter=2, header=None, usecols=[1, 2] + list(range(6,17)))
  df1.columns = ['id', 'fakulta', 'celkem_ZCR', 'prez_celkem_ZCR', 'prez_bc_ZCR', 'prez_mgr_ZCR', 'prez_nmgr_ZCR', 'prez_phd_ZCR', 'komb_celkem_ZCR', 'komb_bc_ZCR', 'komb_mgr_ZCR', 'komb_nmgr_ZCR', 'komb_phd_ZCR']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]

  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  
  # nakonec spojit df a df1
  df_ZCR = pd.concat([df_ZCR, df1], ignore_index=True, sort=False)

# %%
df_ZCR
# Out:
#          id  ...                                      skola
# 0     11110  ...                         Univerzita Karlova
# 1     11120  ...                         Univerzita Karlova
# 2     11130  ...                         Univerzita Karlova
# 3     11140  ...                         Univerzita Karlova
# 4     11150  ...                         Univerzita Karlova
# ...     ...  ...                                        ...
# 1196  51110  ...           Akademie múzických umění v Praze
# 1197  51210  ...           Akademie múzických umění v Praze
# 1198  51310  ...           Akademie múzických umění v Praze
# 1199  54510  ...  Janáčkova akademie múzických umění v Brně
# 1200  54530  ...  Janáčkova akademie múzických umění v Brně
#
# [1201 rows x 16 columns]

# %%
print(df.shape)
print(df_ZCR.shape)
#sloučit tabulku k df
df = df.merge(df_ZCR,how='outer', on=['id', 'id_skola', 'rok', 'skola', 'fakulta'])
print(df.shape)
# Out:
# (1201, 49)
# (1201, 16)
# (1201, 60)

# %%
#TABULKA 6: https://dsia.msmt.cz//vystupy/f2/f21z_ciz.xlsx (studentky ženy pouze cizinky) 2011 - 2018
#názvy sloupců - přípona ZCI
# přejmenováva df a sloupce a změna nazvu souboru
df_ZCI = pd.DataFrame(columns=['id', 'fakulta', 'celkem_ZCI', 'prez_celkem_ZCI', 'prez_bc_ZCI', 'prez_mgr_ZCI', 'prez_nmgr_ZCI', 'prez_phd_ZCI', 'komb_celkem_ZCI', 'komb_bc_ZCI', 'komb_mgr_ZCI', 'komb_nmgr_ZCI', 'komb_phd_ZCI'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f2/f21z_ciz.xlsx', sheet_name=rok, skiprows=9, skipfooter=2, header=None, usecols=[1, 2] + list(range(6,17)))
  df1.columns = ['id', 'fakulta', 'celkem_ZCI', 'prez_celkem_ZCI', 'prez_bc_ZCI', 'prez_mgr_ZCI', 'prez_nmgr_ZCI', 'prez_phd_ZCI', 'komb_celkem_ZCI', 'komb_bc_ZCI', 'komb_mgr_ZCI', 'komb_nmgr_ZCI', 'komb_phd_ZCI']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]
 
  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  #
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  
  
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  #
  # nakonec spojit df a df1
  df_ZCI = pd.concat([df_ZCI, df1], ignore_index=True, sort=False)

# %%
df_ZCI
# Out:
#          id  ...                                      skola
# 0     11110  ...                         Univerzita Karlova
# 1     11120  ...                         Univerzita Karlova
# 2     11130  ...                         Univerzita Karlova
# 3     11140  ...                         Univerzita Karlova
# 4     11150  ...                         Univerzita Karlova
# ...     ...  ...                                        ...
# 1190  51110  ...           Akademie múzických umění v Praze
# 1191  51210  ...           Akademie múzických umění v Praze
# 1192  51310  ...           Akademie múzických umění v Praze
# 1193  54510  ...  Janáčkova akademie múzických umění v Brně
# 1194  54530  ...  Janáčkova akademie múzických umění v Brně
#
# [1195 rows x 16 columns]

# %%
print(df.shape)
print(df_ZCI.shape)
#sloučit tabulku k df
df = df.merge(df_ZCI,how='outer', on=['id', 'id_skola', 'rok', 'skola', 'fakulta'])
print(df.shape)
# Out:
# (1201, 60)
# (1195, 16)
# (1201, 71)

# %%
#TABULKA 7: https://dsia.msmt.cz//vystupy/f2/f25.xlsx (studenti podle bydliště) 2011 - 2018
#názvy sloupců - přípona byd
# přejmenováva df a sloupce a změna nazvu souboru
df_byd = pd.DataFrame(columns=['id', 'fakulta', 'celkem_byd', 'cr_celkem', 'praha', 'stred_cech', 'jih_cech', 'plzen', 'karlovar', 'ustecky', 'liberec', 'kralhrad', 'pardubic', 'vysocina', 'jihomor', 'olomouc', 'zlin', 'mskraj', 'neuvedeno_byd', 'zahranici_byd', 'cizinci_byd'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f2/f25.xlsx', sheet_name=rok, skiprows=9, skipfooter=2, header=None, usecols=[1, 2] + list(range(6,25)))
  df1.columns = ['id', 'fakulta', 'celkem_byd', 'cr_celkem', 'praha', 'stred_cech', 'jih_cech', 'plzen', 'karlovar', 'ustecky', 'liberec', 'kralhrad', 'pardubic', 'vysocina', 'jihomor', 'olomouc', 'zlin', 'mskraj', 'neuvedeno_byd', 'zahranici_byd', 'cizinci_byd']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]

  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  #
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  #
  #
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  #
  # nakonec spojit df a df1
  df_byd = pd.concat([df_byd, df1], ignore_index=True, sort=False)

# %%
df_byd
# Out:
#          id  ...                                      skola
# 0     11110  ...                         Univerzita Karlova
# 1     11120  ...                         Univerzita Karlova
# 2     11130  ...                         Univerzita Karlova
# 3     11140  ...                         Univerzita Karlova
# 4     11150  ...                         Univerzita Karlova
# ...     ...  ...                                        ...
# 1196  51110  ...           Akademie múzických umění v Praze
# 1197  51210  ...           Akademie múzických umění v Praze
# 1198  51310  ...           Akademie múzických umění v Praze
# 1199  54510  ...  Janáčkova akademie múzických umění v Brně
# 1200  54530  ...  Janáčkova akademie múzických umění v Brně
#
# [1201 rows x 24 columns]

# %%
print(df.shape)
print(df_byd.shape)
#sloučit tabulku k df
df = df.merge(df_byd,how='outer', on=['id', 'id_skola', 'rok', 'skola', 'fakulta'])
print(df.shape)
# Out:
# (1201, 71)
# (1201, 24)
# (1201, 90)

# %%
#TABULKA 8: https://dsia.msmt.cz//vystupy/f4/f41.xlsx  (levá část tabulky - absolventi včetně cizinců, pravá část tabulky rozlišuje ženy ve všech formách studia)
#názvy sloupců - přípona A pro levou část tabulky, AZ pro pravou část tabulky
# přejmenovává df a sloupce a změna nazvu souboru

df_A_AZ = pd.DataFrame(columns=['id', 'fakulta', 'celkem_A', 'prez_celkem_A', 'prez_bc_A', 'prez_mgr_A', 'prez_nmgr_A', 'prez_phd_A',
                                'komb_celkem_A', 'komb_bc_A', 'komb_mgr_A', 'komb_nmgr_A', 'komb_phd_A', 'celkem_AZ', 'prez_celkem_AZ',
                                'prez_bc_AZ', 'prez_mgr_AZ', 'prez_nmgr_AZ', 'prez_phd_AZ', 'komb_celkem_AZ', 'komb_bc_AZ', 'komb_mgr_AZ',
                                'komb_nmgr_AZ', 'komb_phd_AZ'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f4/f41.xlsx', sheet_name=rok, skiprows=8, skipfooter=2, header=None,
                      usecols=[1, 2] + list(range(6,28)))
  df1.columns = ['id', 'fakulta', 'celkem_A', 'prez_celkem_A', 'prez_bc_A', 'prez_mgr_A', 'prez_nmgr_A', 'prez_phd_A', 'komb_celkem_A',
                 'komb_bc_A', 'komb_mgr_A', 'komb_nmgr_A', 'komb_phd_A', 'celkem_AZ', 'prez_celkem_AZ', 'prez_bc_AZ', 'prez_mgr_AZ',
                 'prez_nmgr_AZ', 'prez_phd_AZ', 'komb_celkem_AZ', 'komb_bc_AZ', 'komb_mgr_AZ', 'komb_nmgr_AZ', 'komb_phd_AZ']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]
 
  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  #
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  #
  # nakonec spojit df a df1
  df_A_AZ = pd.concat([df_A_AZ, df1], ignore_index=True, sort=False)

# %%
df_A_AZ
# Out:
#          id  ...                                      skola
# 0     11110  ...                         Univerzita Karlova
# 1     11120  ...                         Univerzita Karlova
# 2     11130  ...                         Univerzita Karlova
# 3     11140  ...                         Univerzita Karlova
# 4     11150  ...                         Univerzita Karlova
# ...     ...  ...                                        ...
# 1193  51110  ...           Akademie múzických umění v Praze
# 1194  51210  ...           Akademie múzických umění v Praze
# 1195  51310  ...           Akademie múzických umění v Praze
# 1196  54510  ...  Janáčkova akademie múzických umění v Brně
# 1197  54530  ...  Janáčkova akademie múzických umění v Brně
#
# [1198 rows x 27 columns]

# %%
print(df.shape)
print(df_A_AZ.shape)
#sloučit tabulku k df
df = df.merge(df_A_AZ,how='outer', on=['id', 'id_skola', 'rok', 'skola', 'fakulta'])
print(df.shape)
# Out:
# (1201, 90)
# (1198, 27)
# (1202, 112)

# %%
#TABULKA 9: https://dsia.msmt.cz//vystupy/f4/f41_cr.xlsx (levá část tabulky - absolventi, pouze občani ČR, pravá část tabulky ženy)
#názvy sloupců - přípona ACR pro levou část tabulky, AZCR pro pravou část tabulky
# přejmenovává df a sloupce a změna nazvu souboru

df_ACR_AZCR = pd.DataFrame(columns=['id', 'fakulta', 'celkem_ACR', 'prez_celkem_ACR', 'prez_bc_ACR', 'prez_mgr_ACR', 'prez_nmgr_ACR', 'prez_phd_ACR',
                                'komb_celkem_ACR', 'komb_bc_ACR', 'komb_mgr_ACR', 'komb_nmgr_ACR', 'komb_phd_ACR', 'celkem_AZCR', 'prez_celkem_AZCR',
                                'prez_bc_AZCR', 'prez_mgr_AZCR', 'prez_nmgr_AZCR', 'prez_phd_AZCR', 'komb_celkem_AZCR', 'komb_bc_AZCR', 'komb_mgr_AZCR',
                                'komb_nmgr_AZCR', 'komb_phd_AZCR'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f4/f41_cr.xlsx', sheet_name=rok, skiprows=8, skipfooter=2, header=None,
                      usecols=[1, 2] + list(range(6,28)))
  df1.columns = ['id', 'fakulta', 'celkem_ACR', 'prez_celkem_ACR', 'prez_bc_ACR', 'prez_mgr_ACR', 'prez_nmgr_ACR', 'prez_phd_ACR',
                                'komb_celkem_ACR', 'komb_bc_ACR', 'komb_mgr_ACR', 'komb_nmgr_ACR', 'komb_phd_ACR', 'celkem_AZCR', 'prez_celkem_AZCR',
                                'prez_bc_AZCR', 'prez_mgr_AZCR', 'prez_nmgr_AZCR', 'prez_phd_AZCR', 'komb_celkem_AZCR', 'komb_bc_AZCR', 'komb_mgr_AZCR',
                                'komb_nmgr_AZCR', 'komb_phd_AZCR']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]
  
  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  #
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  #
  #
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  #
  # nakonec spojit df a df1
  df_ACR_AZCR = pd.concat([df_ACR_AZCR, df1], ignore_index=True, sort=False)

# %%
df_ACR_AZCR
# Out:
#          id  ...                                      skola
# 0     11110  ...                         Univerzita Karlova
# 1     11120  ...                         Univerzita Karlova
# 2     11130  ...                         Univerzita Karlova
# 3     11140  ...                         Univerzita Karlova
# 4     11150  ...                         Univerzita Karlova
# ...     ...  ...                                        ...
# 1193  51110  ...           Akademie múzických umění v Praze
# 1194  51210  ...           Akademie múzických umění v Praze
# 1195  51310  ...           Akademie múzických umění v Praze
# 1196  54510  ...  Janáčkova akademie múzických umění v Brně
# 1197  54530  ...  Janáčkova akademie múzických umění v Brně
#
# [1198 rows x 27 columns]

# %%
print(df.shape)
print(df_ACR_AZCR.shape)
#sloučit tabulku k df
df = df.merge(df_ACR_AZCR,how='outer', on=['id', 'id_skola', 'rok', 'skola', 'fakulta'])
print(df.shape)
# Out:
# (1202, 112)
# (1198, 27)
# (1202, 134)

# %%
# TABULKA 10: https://dsia.msmt.cz//vystupy/f4/f41_ciz.xlsx (levá část tabulky - absolventi, pouze cizinci, druhá část tabulky ženy cizinky)
# názvy sloupců - přípona ACI pro levou část tabulky, AZCI pro pravou část tabulky
# přejmenovává df a sloupce a změna nazvu souboru

df_ACI_AZCI = pd.DataFrame(columns=['id', 'fakulta', 'celkem_ACI', 'prez_celkem_ACI', 'prez_bc_ACI', 'prez_mgr_ACI', 'prez_nmgr_ACI', 'prez_phd_ACI',
                                'komb_celkem_ACI', 'komb_bc_ACI', 'komb_mgr_ACI', 'komb_nmgr_ACI', 'komb_phd_ACI', 'celkem_AZCI', 'prez_celkem_AZCI',
                                'prez_bc_AZCI', 'prez_mgr_AZCI', 'prez_nmgr_AZCI', 'prez_phd_AZCI', 'komb_celkem_AZCI', 'komb_bc_AZCI', 'komb_mgr_AZCI',
                                'komb_nmgr_AZCI', 'komb_phd_AZCI'])

for rok in roky:
  df1 = pd.read_excel('https://dsia.msmt.cz//vystupy/f4/f41_ciz.xlsx', sheet_name=rok, skiprows=8, skipfooter=2, header=None,
                      usecols=[1, 2] + list(range(6,28)))
  df1.columns = ['id', 'fakulta', 'celkem_ACI', 'prez_celkem_ACI', 'prez_bc_ACI', 'prez_mgr_ACI', 'prez_nmgr_ACI', 'prez_phd_ACI',
                                'komb_celkem_ACI', 'komb_bc_ACI', 'komb_mgr_ACI', 'komb_nmgr_ACI', 'komb_phd_ACI', 'celkem_AZCI', 'prez_celkem_AZCI',
                                'prez_bc_AZCI', 'prez_mgr_AZCI', 'prez_nmgr_AZCI', 'prez_phd_AZCI', 'komb_celkem_AZCI', 'komb_bc_AZCI', 'komb_mgr_AZCI',
                                'komb_nmgr_AZCI', 'komb_phd_AZCI']
  df1['rok'] = rok 
  #vytvoreni noveho sloupce id_skola, kde je RID skoly(prvni dva znaky z ID fakulty)
  df1['id_skola']=df1['id'].str[0:2]
  
  # vybrat VVŠ podle číselníku
  df1 = df1[df1.id_skola.isin(vvs)]
  #
  # zahodit souhrny za VŠ 
  df1.drop(df1[df1.id.str[-3:] == '000'].index, inplace=True)
  #
  #
  # přidat názvy VŠ
  df1['skola'] = df1.id_skola.map(kody_vs)
  #
  # nakonec spojit df a df1
  df_ACI_AZCI = pd.concat([df_ACI_AZCI, df1], ignore_index=True, sort=False)

# %%
df_ACI_AZCI
# Out:
#          id  ...                                      skola
# 0     11110  ...                         Univerzita Karlova
# 1     11120  ...                         Univerzita Karlova
# 2     11130  ...                         Univerzita Karlova
# 3     11140  ...                         Univerzita Karlova
# 4     11150  ...                         Univerzita Karlova
# ...     ...  ...                                        ...
# 1134  51110  ...           Akademie múzických umění v Praze
# 1135  51210  ...           Akademie múzických umění v Praze
# 1136  51310  ...           Akademie múzických umění v Praze
# 1137  54510  ...  Janáčkova akademie múzických umění v Brně
# 1138  54530  ...  Janáčkova akademie múzických umění v Brně
#
# [1139 rows x 27 columns]

# %%
print(df.shape)
print(df_ACI_AZCI.shape)
#sloučit tabulku k df
df = df.merge(df_ACI_AZCI,how='outer', on=['id', 'id_skola', 'rok', 'skola', 'fakulta'])
print(df.shape)
# Out:
# (1202, 134)
# (1139, 27)
# (1202, 156)

# %%
df
# Out:
#          id                             fakulta  ... komb_nmgr_AZCI komb_phd_AZCI
# 0     11110                 1. lékařská fakulta  ...            0.0           5.0
# 1     11120                 3. lékařská fakulta  ...            0.0           2.0
# 2     11130                 2. lékařská fakulta  ...            0.0           0.0
# 3     11140            Lékařská fakulta v Plzni  ...            0.0           0.0
# 4     11150  Lékařská fakulta v Hradci  Králové  ...            0.0           1.0
# ...     ...                                 ...  ...            ...           ...
# 1197  51210                   Divadelní fakulta  ...            0.0           0.0
# 1198  51310         Filmová a televizní fakulta  ...            0.0           0.0
# 1199  54510                     Hudební fakulta  ...            0.0           0.0
# 1200  54530                   Divadelní fakulta  ...            3.0           0.0
# ...

# %%
# export výsledné tabulky do csv
from google.colab import files
df.to_csv('DataMsmt.csv', encoding='1250') 
files.download('DataMsmt.csv')

# %%
print(df)

# %%
print(df.columns)
